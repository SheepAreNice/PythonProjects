# %% [markdown]
# <a href="https://colab.research.google.com/github/SheepAreNice/PythonProjects/blob/master/Assignment1_Group2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="background-color: #d0e7ff; padding: 15px; border-radius: 5px; font-family: 'Georgia', serif;">
#   <h1 style="font-size: 4em; margin: 0 0 0.3em 0;">Assignment 1</h1>
#   <h2 style="font-size: 2.5em; margin: 0;">Regression Modelling & Evaluations</h2>
# </div>

# %% [markdown]
# <div style="background-color: #d0e7ff; padding: 10px; border-radius: 5px;">
#
#
#
# This assignment involves building a regression model to predict the `wage_eur` column in a dataset of FIFA soccer players.
#
# However, you will not be graded on finding "the best" model. Instead, your grade will be based on:
# - The decisions you make based on your own data exploration
# - Your ability to explain and justify those decisions
# - How you iterate based on failures and unexpected outcomes
#
# You are encouraged to try multiple models, feature sets, or evaluation metrics, but more importantly, explain **why** you made those choices.
# </div>

# %% [markdown]
# <span style="color:red; font-weight:bold; font-size:18px;">Please rename your file to <mark>Assignment1_Group [your group number]</mark></span>

# %% [markdown]
# <div style="background-color: #e6f0ff; padding: 15px; border-radius: 5px; font-family: 'Georgia', serif;">
#
#
# # 🟦 Part 1: Coding & Modelling
#
# Your task in this section is to complete the code-based analysis using the provided dataset.
#
# Follow the TODOs in the code cells below to:
# - Load and explore the data
# - Select and engineer features
# - Train and evaluate a regression model
# - Reflect and iterate based on your findings
#
# Remember: focus on **your decision-making** and **how you respond to your data**.
#
# </div>
#
# ---

# %% [markdown]
# ## 1.0. Import ALL the Libraries used

# %%
# TO DO import the libraries

# %% [markdown]
# ## 1.1. Load & Preview Data

# %%
# TODO: Load the data
# Load the dataset and carry out the initial data analysis
# Tip: Use df.info(), df.describe(), and df.isnull().sum() to explore missing values and structure.
import pandas as pd

# %% [markdown]
# ## 1.2. Clean  & Transform the Data

# %%
# TODO: Clean the data
# Identify and remove or impute missing or irrelevant features.
# Document why certain features are dropped or kept based on data types, missing values, or relevance.

# Example: Check for null values and data types

# %% [markdown]
# ## 1.3. Feature Selection

# %%
# TODO: Feature selection
# Use correlation analysis or domain logic to select relevant features for modelling.
# Consider removing features with very high correlation or low variance.

import seaborn as sns
import matplotlib.pyplot as plt

# Example: Correlation heatmap

# %% [markdown]
# ## 1.4. Prepare Train-Test Split

# %%
# TODO: Prepare train-test split
# Choose your target variable (wage_eur) and create a train-test split.
# Justify your split ratio (e.g., 80/20 or 70/30).

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1.5. Train a Regression Model

# %%
# TODO: Build and train a regression model
# Train one or more regression models (e.g., Linear Regression, DecisionTreeRegressor, etc.)
# Explain your choice and any hyperparameters you've tuned.

# %% [markdown]
# <div style="background-color: #e6f0ff; padding: 15px; border-radius: 5px; font-family: 'Georgia', serif;">
#
#  # 📘 Part 2: Process Summary & Reflection</h2>
#
#   <p>In this section, explain your modelling journey in your own words. Use bullet points or short paragraphs to describe what you did, why you did it, and how it turned out. Focus on the <strong>specific decisions and outcomes</strong> from your own process,and avoid generic or templated responses.</p>
#
#   <p><em>Tip:</em> Your explanation should match the steps and outcomes in your code. This section is where you demonstrate <strong>your thinking and learning</strong>, not just code output.</p>
#
# </div>
#
# ---

# %% [markdown]
# - **2.1. Initial Approach**
#   What was your original plan or hypothesis for predicting `wage_eur`?

# %% [markdown]
# - **2.2. Data Preparation**
#   What cleaning or transformation steps did you take? Did you remove or impute any values? Why?

# %% [markdown]
# - **2.3. Feature Selection**
#   How did you choose which variables to use? Did you remove any due to correlation, irrelevance, or low variance?

# %% [markdown]
# - **2.4. Modelling Techniques**
#   What model(s) did you use and why? Did you test alternatives?

# %% [markdown]
# - **2.5. Evaluation Strategy**
#   What metric(s) did you use to evaluate performance? Why were they appropriate for your problem?

# %% [markdown]
# - **2.6. Challenges & Surprises**
#   What unexpected result did you encounter? How did you adapt or revise your process?

# %% [markdown]
# - **2.7. Visual Insights**
#   Include a **visualzation** or brief description of a visualization that influenced a key decision.

# %% [markdown]
# - **2.8. Final Outcome**
#   What result did your final model achieve on the test set? How confident are you in its performance?
